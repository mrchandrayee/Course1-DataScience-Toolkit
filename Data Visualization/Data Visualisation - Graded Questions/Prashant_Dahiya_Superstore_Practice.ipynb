# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('default')

# %%
df = pd.read_csv('/content/drive/MyDrive/MS Aug 23/Course 1 - Data Science Tool Kit (Preparatory Content)/Data Visualization/Data Visualisation - Graded Questions/Sample - Superstore.csv',encoding='latin1')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.size
# Out:
# 209874

# %%
df['Postal Code'] = df['Postal Code'].astype(object)
df['Row ID'] = df['Row ID'].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   object
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   object
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#               Sales     Quantity     Discount       Profit
# count   9994.000000  9994.000000  9994.000000  9994.000000
# mean     229.858001     3.789574     0.156203    28.656896
# std      623.245101     2.225110     0.206452   234.260108
# min        0.444000     1.000000     0.000000 -6599.978000
# 25%       17.280000     2.000000     0.000000     1.728750
# 50%       54.490000     3.000000     0.200000     8.666500
# 75%      209.940000     5.000000     0.200000    29.364000
# max    22638.480000    14.000000     0.800000  8399.976000

# %%
plt.figure(figsize=[10,6])
df.boxplot()
plt.show()

# %%
sns.boxplot(data=df[['Sales','Quantity','Discount','Profit']])
# Out:
# <Axes: >

# %%
sns.boxplot(data=df, x='Category', y='Discount')
# Out:
# <Axes: xlabel='Category', ylabel='Discount'>

# %%
df.groupby(['Category','Sub-Category'])[['Sales','Profit']].mean()
# Out:
#                                     Sales      Profit
# Category        Sub-Category
# Furniture       Bookcases      503.859633  -15.230509
#                 Chairs         532.332420   43.095894
#                 Furnishings     95.825668   13.645918
#                 Tables         648.794771  -55.565771
# Office Supplies Appliances     230.755710   38.922758
#                 Art             34.068834    8.200737
#                 Binders        133.560560   19.843574
#                 Envelopes       64.867724   27.418019
#                 Fasteners       13.936774    4.375660
#                 Labels          34.303055   15.236962
#                 Paper           57.284092   24.856620
#                 Storage        264.590553   25.152277
#                 Supplies       245.650200   -6.258418
# Technology      Accessories    215.974604   54.111788
#                 Copiers       2198.941618  817.909190
#                 Machines      1645.553313   29.432669
# ...

# %%
pd.pivot_table(data=df, index='Category', columns='Sub-Category', values='Sales', aggfunc=np.mean)
# Out:
# Sub-Category     Accessories  Appliances        Art    Binders   Bookcases  \
# Category
# Furniture                NaN         NaN        NaN        NaN  503.859633
# Office Supplies          NaN   230.75571  34.068834  133.56056         NaN
# Technology        215.974604         NaN        NaN        NaN         NaN
#
# Sub-Category        Chairs      Copiers  Envelopes  Fasteners  Furnishings  \
# Category
# Furniture        532.33242          NaN        NaN        NaN    95.825668
# Office Supplies        NaN          NaN  64.867724  13.936774          NaN
# Technology             NaN  2198.941618        NaN        NaN          NaN
#
# Sub-Category        Labels     Machines      Paper      Phones     Storage  \
# Category
# Furniture              NaN          NaN        NaN         NaN         NaN
# Office Supplies  34.303055          NaN  57.284092         NaN  264.590553
# Technology             NaN  1645.553313        NaN  371.211534         NaN
#
# ...

# %%
pd.pivot_table(data=df, index='Region', columns='Category', values='Sales', aggfunc=np.mean)
# Out:
# Category   Furniture  Office Supplies  Technology
# Region
# Central   340.534644       117.458801  405.753124
# East      346.574383       120.044425  495.278469
# South     353.309289       126.282727  507.753952
# West      357.302325       116.422377  420.687533

# %%
pt = pd.pivot_table(data=df, index='Segment', columns='Ship Mode', values='Sales', aggfunc=np.mean)
pt
# Out:
# Ship Mode    First Class    Same Day  Second Class  Standard Class
# Segment
# Consumer      206.981749  191.155707    226.959755      230.190299
# Corporate     218.264886  395.801079    239.944234      225.739810
# Home Office   304.228831  202.191455    258.128421      223.191537

# %%
sns.heatmap(data=pt, cmap="Greens", annot=True, fmt='.2f')
# Out:
# <Axes: xlabel='Ship Mode', ylabel='Segment'>

# %%
sns.barplot(data=df, x='Region', y='Sales')
# Out:
# <Axes: xlabel='Region', ylabel='Sales'>

# %%
df.groupby(['Category'])['Profit'].mean().plot.pie()
# Out:
# <Axes: ylabel='Profit'>

# %%
sns.barplot(data=df, x='Category', y='Sales', estimator=np.mean)
# Out:
# <Axes: xlabel='Category', ylabel='Sales'>

# %%
sns.displot(df['Quantity'], bins=10)

# %%
plt.scatter(df.Sales,df.Profit)

# %%
sns.jointplot(data=df, x='Sales', y='Profit')

# %%
sns.pairplot(data=df, vars=['Sales','Quantity','Discount','Profit'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   object
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   object
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   object
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   object
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %% [markdown]
# ### Check the Website
# https://strftime.org/

# %%
df['OD_Year']=df['Order Date'].dt.year
df['OD_Month']=df['Order Date'].dt.strftime('%b')
df['OD_Month_No']=df['Order Date'].dt.month
df['SD_Year']=df['Ship Date'].dt.year
df['SD_Month']=df['Ship Date'].dt.strftime('%b')
df['SD_Month_No']=df['Ship Date'].dt.month
df
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0         1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1         2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2         3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3         4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4         5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# ...     ...             ...        ...        ...             ...         ...
# 9989   9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990   9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991   9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992   9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993   9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
# ...

# %%
sns.barplot(data=df, x='OD_Year', y='Sales')
# Out:
# <Axes: xlabel='OD_Year', ylabel='Sales'>

# %%
pd.pivot_table(data=df, index=['OD_Year','OD_Month'], columns='Sub-Category', values='Sales', aggfunc=np.mean)
# Out:
# Sub-Category      Accessories  Appliances         Art     Binders  \
# OD_Year OD_Month
# 2014    Apr        195.845385  177.526667   35.494750   54.764000
#         Aug        149.056462  209.675300   20.366200  163.514885
#         Dec        232.440435  189.085000   97.673867  147.435067
#         Feb        224.198000   44.960000   36.832000   26.097077
#         Jan        275.963333  156.290000   19.665556   67.875667
#         Jul        254.514769   20.435000   21.336667  122.270500
#         Jun        133.408000  325.035143   36.111158  194.354227
#         Mar        138.616750  100.592400   18.784909   69.348864
#         May         77.276667  114.824500   32.024444  230.121263
#         Nov        146.741545  202.602462   29.219810  151.006381
#         Oct        117.834000  107.698000   61.502889   19.206240
#         Sep        129.450421  127.013895   37.993000  344.422054
# 2015    Apr        137.252500  272.226500   28.072588  214.564909
# ...

# %%
pd.pivot_table(data=df, index=['OD_Year','OD_Month_No'], columns='Sub-Category', values='Sales', aggfunc=np.mean)
# Out:
# Sub-Category         Accessories  Appliances         Art     Binders  \
# OD_Year OD_Month_No
# 2014    1             275.963333  156.290000   19.665556   67.875667
#         2             224.198000   44.960000   36.832000   26.097077
#         3             138.616750  100.592400   18.784909   69.348864
#         4             195.845385  177.526667   35.494750   54.764000
#         5              77.276667  114.824500   32.024444  230.121263
#         6             133.408000  325.035143   36.111158  194.354227
#         7             254.514769   20.435000   21.336667  122.270500
#         8             149.056462  209.675300   20.366200  163.514885
#         9             129.450421  127.013895   37.993000  344.422054
#         10            117.834000  107.698000   61.502889   19.206240
#         11            146.741545  202.602462   29.219810  151.006381
#         12            232.440435  189.085000   97.673867  147.435067
# ...

# %%
pt2 = pd.pivot_table(data=df, index='OD_Month', columns='OD_Year', values='Sales')
pt2
# Out:
# OD_Year         2014        2015        2016        2017
# OD_Month
# Apr       209.595148  213.720053  227.941406  179.909045
# Aug       182.414827  232.064982  176.791899  289.545358
# Dec       250.164103  237.087092  275.565463  181.448742
# Feb        98.258522  186.740797  276.853193  189.730219
# Jan       180.213861  313.346131  208.342596  283.686284
# Jul       237.387364  205.466607  195.333149  200.285027
# Jun       256.260204  179.690522  202.736352  216.251942
# Mar       354.719803  280.625014  317.275307  247.362827
# May       193.838418  206.381414  253.278791  182.897150
# Nov       247.260115  234.483221  214.626935  258.056264
# Oct       197.820082  189.186286  304.529311  260.996387
# Sep       305.139369  220.463884  202.231474  191.430614

# %%
sns.heatmap(data=pt2, cmap="Greens", annot=True, fmt='.2f')
# Out:
# <Axes: xlabel='OD_Year', ylabel='OD_Month'>

# %%
pt3 = pd.pivot_table(data=df, index='OD_Month_No', columns='OD_Year', values='Sales')
pt3
# Out:
# OD_Year            2014        2015        2016        2017
# OD_Month_No
# 1            180.213861  313.346131  208.342596  283.686284
# 2             98.258522  186.740797  276.853193  189.730219
# 3            354.719803  280.625014  317.275307  247.362827
# 4            209.595148  213.720053  227.941406  179.909045
# 5            193.838418  206.381414  253.278791  182.897150
# 6            256.260204  179.690522  202.736352  216.251942
# 7            237.387364  205.466607  195.333149  200.285027
# 8            182.414827  232.064982  176.791899  289.545358
# 9            305.139369  220.463884  202.231474  191.430614
# 10           197.820082  189.186286  304.529311  260.996387
# 11           247.260115  234.483221  214.626935  258.056264
# 12           250.164103  237.087092  275.565463  181.448742

# %%
sns.heatmap(data=pt3, cmap="Greens", annot=True, fmt='.2f')
# Out:
# <Axes: xlabel='OD_Year', ylabel='OD_Month_No'>

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df[~(df['Region']=='West')]['Region'].value_counts()
# Out:
# Region
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df[(df['Profit']>0) & (df['Sales']>20)]
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0         1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1         2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 4         5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5         6  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7         8  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# ...     ...             ...        ...        ...             ...         ...
# 9989   9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class    TB-21400
# 9990   9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9991   9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9992   9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class    DB-13060
# 9993   9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class    CC-12220
#
# ...

# %%
df[(df['Profit']>0) & (df['Sales']>20)][['Profit','Sales']]
# Out:
#         Profit    Sales
# 0      41.9136  261.960
# 1     219.5820  731.940
# 4       2.5164   22.368
# 5      14.1694   48.860
# 7      90.7152  907.152
# ...        ...      ...
# 9989    4.1028   25.248
# 9990   15.6332   91.960
# 9991   19.3932  258.576
# 9992   13.3200   29.600
# 9993   72.9480  243.160
#
# [5806 rows x 2 columns]

# %%
df[~(df['Profit']>0) & (df['Sales']>20)][['Profit','Sales']]
# Out:
#          Profit      Sales
# 3     -383.0310   957.5775
# 14    -123.8580    68.8100
# 23      -1.0196    71.3720
# 27   -1665.0522  3083.4300
# 36    -147.9630   190.9200
# ...         ...        ...
# 9919  -143.4310   528.4300
# 9920   -35.8176    22.3860
# 9931   -40.1960   683.3320
# 9937    -1.7772    71.0880
# 9962   -67.6704   383.4656
#
# [1335 rows x 2 columns]

# %%
df[(df['Profit']>0) & ~(df['Sales']>20)][['Profit','Sales']]
# Out:
#       Profit   Sales
# 2     6.8714  14.620
# 6     1.9656   7.280
# 8     5.7825  18.504
# 12    5.4432  15.552
# 18    2.4824   8.560
# ...      ...     ...
# 9965  2.3406   4.980
# 9974  5.2332  18.690
# 9975  6.4128  13.360
# 9978  4.6816  13.376
# 9981  5.3690  16.520
#
# [2252 rows x 2 columns]
