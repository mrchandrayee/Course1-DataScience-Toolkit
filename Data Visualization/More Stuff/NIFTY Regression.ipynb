# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.style.use('default')

# %%
df = pd.read_csv('^NSEI.csv')
df
# Out:
#            Date          Open          High           Low         Close  \
# 0    2008-01-01   6136.750000   6357.100098   4448.500000   5137.450195
# 1    2008-02-01   5140.600098   5545.200195   4803.600098   5223.500000
# 2    2008-03-01   5222.799805   5222.799805   4468.549805   4734.500000
# 3    2008-04-01   4735.649902   5230.750000   4628.750000   5165.899902
# 4    2008-05-01   5265.299805   5298.850098   4801.899902   4870.100098
# ..          ...           ...           ...           ...           ...
# 184  2023-05-01  18124.800781  18662.449219  18042.400391  18534.400391
# 185  2023-06-01  18579.400391  19201.699219  18464.550781  19189.050781
# 186  2023-07-01  19246.500000  19991.849609  19234.400391  19753.800781
# 187  2023-08-01  19784.000000  19795.599609  19223.650391  19253.800781
# 188  2023-09-01  19258.150391  19867.150391  19255.699219  19819.949219
#
#         Adj Close   Volume
# 0     5137.450195        0
# 1     5223.500000        0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       189 non-null    object
#  1   Open       189 non-null    float64
#  2   High       189 non-null    float64
#  3   Low        189 non-null    float64
#  4   Close      189 non-null    float64
#  5   Adj Close  189 non-null    float64
#  6   Volume     189 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 10.5+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       189 non-null    datetime64[ns]
#  1   Open       189 non-null    float64
#  2   High       189 non-null    float64
#  3   Low        189 non-null    float64
#  4   Close      189 non-null    float64
#  5   Adj Close  189 non-null    float64
#  6   Volume     189 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 10.5 KB

# %%
sns.lineplot(data=df, x='Date', y='Open')
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
plt.scatter(df['Date'],df['Open'])

# %%
sns.jointplot(data=df, x='Date', y='Open')

# %%
sns.pairplot(data=df, kind='reg', plot_kws={'line_kws':{'color': 'cyan'}})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       189 non-null    datetime64[ns]
#  1   Open       189 non-null    float64
#  2   High       189 non-null    float64
#  3   Low        189 non-null    float64
#  4   Close      189 non-null    float64
#  5   Adj Close  189 non-null    float64
#  6   Volume     189 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 10.5 KB

# %%
sns.jointplot(data=df, x='Close', y='Open', kind='reg', joint_kws={'line_kws':{'color': 'cyan'}})

# %%
np.float64(df['Date'])
# Out:
# array([1.1991456e+18, 1.2018240e+18, 1.2043296e+18, 1.2070080e+18,
#        1.2096000e+18, 1.2122784e+18, 1.2148704e+18, 1.2175488e+18,
#        1.2202272e+18, 1.2228192e+18, 1.2254976e+18, 1.2280896e+18,
#        1.2307680e+18, 1.2334464e+18, 1.2358656e+18, 1.2385440e+18,
#        1.2411360e+18, 1.2438144e+18, 1.2464064e+18, 1.2490848e+18,
#        1.2517632e+18, 1.2543552e+18, 1.2570336e+18, 1.2596256e+18,
#        1.2623040e+18, 1.2649824e+18, 1.2674016e+18, 1.2700800e+18,
#        1.2726720e+18, 1.2753504e+18, 1.2779424e+18, 1.2806208e+18,
#        1.2832992e+18, 1.2858912e+18, 1.2885696e+18, 1.2911616e+18,
#        1.2938400e+18, 1.2965184e+18, 1.2989376e+18, 1.3016160e+18,
#        1.3042080e+18, 1.3068864e+18, 1.3094784e+18, 1.3121568e+18,
#        1.3148352e+18, 1.3174272e+18, 1.3201056e+18, 1.3226976e+18,
#        1.3253760e+18, 1.3280544e+18, 1.3305600e+18, 1.3332384e+18,
#        1.3358304e+18, 1.3385088e+18, 1.3411008e+18, 1.3437792e+18,
# ...

# %%
df['Date_Float']=np.float64(df['Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 189 entries, 0 to 188
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        189 non-null    datetime64[ns]
#  1   Open        189 non-null    float64
#  2   High        189 non-null    float64
#  3   Low         189 non-null    float64
#  4   Close       189 non-null    float64
#  5   Adj Close   189 non-null    float64
#  6   Volume      189 non-null    int64
#  7   Date_Float  189 non-null    float64
# dtypes: datetime64[ns](1), float64(6), int64(1)
# memory usage: 11.9 KB

# %%
df
# Out:
#           Date          Open          High           Low         Close  \
# 0   2008-01-01   6136.750000   6357.100098   4448.500000   5137.450195
# 1   2008-02-01   5140.600098   5545.200195   4803.600098   5223.500000
# 2   2008-03-01   5222.799805   5222.799805   4468.549805   4734.500000
# 3   2008-04-01   4735.649902   5230.750000   4628.750000   5165.899902
# 4   2008-05-01   5265.299805   5298.850098   4801.899902   4870.100098
# ..         ...           ...           ...           ...           ...
# 184 2023-05-01  18124.800781  18662.449219  18042.400391  18534.400391
# 185 2023-06-01  18579.400391  19201.699219  18464.550781  19189.050781
# 186 2023-07-01  19246.500000  19991.849609  19234.400391  19753.800781
# 187 2023-08-01  19784.000000  19795.599609  19223.650391  19253.800781
# 188 2023-09-01  19258.150391  19867.150391  19255.699219  19819.949219
#
#         Adj Close   Volume    Date_Float
# 0     5137.450195        0  1.199146e+18
# ...

# %%
sns.jointplot(data=df, x='Date_Float', y='Open', kind='reg', joint_kws={'line_kws':{'color': 'cyan'}})

# %%
pd.DataFrame(np.float64(pd.to_datetime(['01-01-2008'])))[0]
# Out:
# 0    1.199146e+18
# Name: 0, dtype: float64

# %%
df['Date_Float']
# Out:
# 0      1.199146e+18
# 1      1.201824e+18
# 2      1.204330e+18
# 3      1.207008e+18
# 4      1.209600e+18
#            ...
# 184    1.682899e+18
# 185    1.685578e+18
# 186    1.688170e+18
# 187    1.690848e+18
# 188    1.693526e+18
# Name: Date_Float, Length: 189, dtype: float64

# %%
df['Date_Float2'] = pd.DataFrame(np.float64(pd.to_datetime(['01-01-2008'])))

# %%
df
# Out:
#           Date          Open          High           Low         Close  \
# 0   2008-01-01   6136.750000   6357.100098   4448.500000   5137.450195
# 1   2008-02-01   5140.600098   5545.200195   4803.600098   5223.500000
# 2   2008-03-01   5222.799805   5222.799805   4468.549805   4734.500000
# 3   2008-04-01   4735.649902   5230.750000   4628.750000   5165.899902
# 4   2008-05-01   5265.299805   5298.850098   4801.899902   4870.100098
# ..         ...           ...           ...           ...           ...
# 184 2023-05-01  18124.800781  18662.449219  18042.400391  18534.400391
# 185 2023-06-01  18579.400391  19201.699219  18464.550781  19189.050781
# 186 2023-07-01  19246.500000  19991.849609  19234.400391  19753.800781
# 187 2023-08-01  19784.000000  19795.599609  19223.650391  19253.800781
# 188 2023-09-01  19258.150391  19867.150391  19255.699219  19819.949219
#
#         Adj Close   Volume    Date_Float   Date_Float2
# 0     5137.450195        0  1.199146e+18  1.199146e+18
# ...

# %%
df['Date_Float2'] = df['Date_Float2'].ffill()
df
# Out:
#           Date          Open          High           Low         Close  \
# 0   2008-01-01   6136.750000   6357.100098   4448.500000   5137.450195
# 1   2008-02-01   5140.600098   5545.200195   4803.600098   5223.500000
# 2   2008-03-01   5222.799805   5222.799805   4468.549805   4734.500000
# 3   2008-04-01   4735.649902   5230.750000   4628.750000   5165.899902
# 4   2008-05-01   5265.299805   5298.850098   4801.899902   4870.100098
# ..         ...           ...           ...           ...           ...
# 184 2023-05-01  18124.800781  18662.449219  18042.400391  18534.400391
# 185 2023-06-01  18579.400391  19201.699219  18464.550781  19189.050781
# 186 2023-07-01  19246.500000  19991.849609  19234.400391  19753.800781
# 187 2023-08-01  19784.000000  19795.599609  19223.650391  19253.800781
# 188 2023-09-01  19258.150391  19867.150391  19255.699219  19819.949219
#
#         Adj Close   Volume    Date_Float   Date_Float2
# 0     5137.450195        0  1.199146e+18  1.199146e+18
# ...

# %%
df['Date_Float3'] = df['Date_Float'] - df['Date_Float2']
df
# Out:
#           Date          Open          High           Low         Close  \
# 0   2008-01-01   6136.750000   6357.100098   4448.500000   5137.450195
# 1   2008-02-01   5140.600098   5545.200195   4803.600098   5223.500000
# 2   2008-03-01   5222.799805   5222.799805   4468.549805   4734.500000
# 3   2008-04-01   4735.649902   5230.750000   4628.750000   5165.899902
# 4   2008-05-01   5265.299805   5298.850098   4801.899902   4870.100098
# ..         ...           ...           ...           ...           ...
# 184 2023-05-01  18124.800781  18662.449219  18042.400391  18534.400391
# 185 2023-06-01  18579.400391  19201.699219  18464.550781  19189.050781
# 186 2023-07-01  19246.500000  19991.849609  19234.400391  19753.800781
# 187 2023-08-01  19784.000000  19795.599609  19223.650391  19253.800781
# 188 2023-09-01  19258.150391  19867.150391  19255.699219  19819.949219
#
#         Adj Close   Volume    Date_Float   Date_Float2   Date_Float3
# ...

# %%
sns.lmplot(data=df, x='Date_Float3', y='Open', line_kws={'color': 'cyan'})

# %%
sns.jointplot(data=df, x='Date_Float3', y='Open', kind='reg', joint_kws={'line_kws':{'color': 'cyan'}})

# %%
df['Date_Float2'][1]-df['Date_Float3'][1]
# Out:
# 1.1964672e+18

# %%
(df['Date_Float2'][1]-df['Date_Float3'][1])/(30*24*60*60)
# Out:
# 461600000000.0

# %%
sns.lmplot(data=df, x=df['Date'].dt.date, y='Open', line_kws={'color': 'cyan'})
# Out:
# C:\Users\prdahiya\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:270: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ar = np.asanyarray(ar)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 sns.lmplot(data=df, x=df['Date'].dt.date, y='Open', line_kws={'color': 'cyan'})
#
# File ~\Anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
# ...

# %%
sns.regplot(data=df, x='Date_Float3', y='Open', line_kws={'color': 'cyan'})
# Out:
# <AxesSubplot:xlabel='Date_Float3', ylabel='Open'>
